# %% [markdown]
# # Creating Dataframe by Scrapping Wikipedia

# %%
import pandas as pd
import requests

# %%
#downloading csv
# !wget -q -O 'Geospatial_data.csv' http://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
df1= pd.read_csv('Geospatial_data.csv')
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df2 = pd.read_csv('Main_CSV.csv')

# %%
df = pd.merge(df2, df1, left_on='PostalCode', right_on='Postal Code')
df.head()
# Out:
#    Unnamed: 0 PostalCode           Borough     Neighbourhood Postal Code  \
# 0           2        M3A        North York         Parkwoods         M3A
# 1           3        M4A        North York  Victoria Village         M4A
# 2           4        M5A  Downtown Toronto      Harbourfront         M5A
# 3           5        M5A  Downtown Toronto       Regent Park         M5A
# 4           6        M6A        North York  Lawrence Heights         M6A
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.654260 -79.360636
# 4  43.718518 -79.464763

# %%
df=df.drop(['Postal Code'], axis=1)
df.head(20)
# Out:
#     Unnamed: 0 PostalCode           Borough     Neighbourhood   Latitude  \
# 0            2        M3A        North York         Parkwoods  43.753259
# 1            3        M4A        North York  Victoria Village  43.725882
# 2            4        M5A  Downtown Toronto      Harbourfront  43.654260
# 3            5        M5A  Downtown Toronto       Regent Park  43.654260
# 4            6        M6A        North York  Lawrence Heights  43.718518
# 5            7        M6A        North York    Lawrence Manor  43.718518
# 6            8        M7A      Queen's Park      Not assigned  43.662301
# 7           10        M9A         Etobicoke  Islington Avenue  43.667856
# 8           11        M1B       Scarborough             Rouge  43.806686
# 9           12        M1B       Scarborough           Malvern  43.806686
# 10          14        M3B        North York   Don Mills North  43.745906
# 11          15        M4B         East York  Woodbine Gardens  43.706397
# ...

# %%
df.shape
# Out:
# (212, 6)
